# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from xgboost import XGBRegressor
import os
import pickle
from datetime import datetime
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import time

import warnings

# התעלמות מכל ההתראות
warnings.filterwarnings("ignore")


#pd.set_option('display.max_rows', None)

# %% [markdown]
# # יצירה של פייפליין

# %% [markdown]
# ### קריאה קובץ לבדיקה פנימית

# %%
path ='inputdata\Panel_06.csv'
panel_06_df = pd.read_csv(path)
panel_06_df.isnull().sum()
#panel_06_df.info()
# Out:
# YEAR                                                                   0
# PRACTICE_CODE                                                          0
# POSTCODE                                                            1227
# AST_Prevalence                                                         1
# COPD_Prevalence                                                       10
#                                                                     ...
# Weighted_Total_Percentage_of_adresses_with_private_outdoor_space     464
# SMOK002(percent)                                                    8121
# SMOK004(percent)                                                    8129
# SMOK005(percent)                                                    8140
# Obesity_Prevalence(per_cent)                                        8127
# Length: 85, dtype: int64

# %% [markdown]
# ## פונקציה מספר 1 - החזרת דטא פריים לפי פיצ'רים נבחרים

# %% [markdown]
# חלוקה לקטגוריות

# %%
feature_categories = {
    "Gender": {
        "description": "Demographic data based on gender",
        "columns": [
            "Total_All", "MALE_All", "FEMALE_All", 
            "Male_0_4", "Male_5_9", "Male_10_14", "Male_15_19", "Male_20_24", 
            "Male_25_29", "Male_30_34", "Male_35_39", "Male_40_44", "Male_45_49", 
            "Male_50_54", "Male_55_59", "Male_60_64", "Male_65_69", "Male_70_74", 
            "Male_75_79", "Male_80_84", "Male_85+",
            "Female_0_4", "Female_5_9", "Female_10_14", "Female_15_19", "Female_20_24", 
            "Female_25_29", "Female_30_34", "Female_35_39", "Female_40_44", "Female_45_49", 
            "Female_50_54", "Female_55_59", "Female_60_64", "Female_65_69", "Female_70_74", 
            "Female_75_79", "Female_80_84", "Female_85+"
        ]
    },
    "Asthma": {
        "description": "Asthma-related data",
        "columns": [
             "AST002(percent)", "AST003(percent)", "AST004(percent)"
        ]
    },
    "COPD": {
        "description": "Chronic Obstructive Pulmonary Disease (COPD) related data",
        "columns": [
             "COPD002(percent)", "COPD003(percent)", 
            "COPD004(percent)", "COPD005(percent)", "COPD007(percent)"
        ]
    },
    "Income": {
        "description": "Economic data related to income",
        "columns": [
            "Weighted_Total_annual_income_(£)", "Weighted_Net_annual_income_(£)", 
            "Weighted_Net_annual_income_before_housing_costs_(£)", 
            "Weighted_Net_annual_income_after_housing_costs_(£)"
        ]
    },
    "Deprivation": {
        "description": "Data related to deprivation index",
        "columns": [
            "Weighted_Index_of_Multiple_Deprivation_(IMD)", "Weighted_Income", 
            "Weighted_Employment", "Weighted_Education,_Skills_and_Training", 
            "Weighted_Health_Deprivation_and_Disability", "Weighted_Crime", 
            "Weighted_Barriers_to_Housing_and_Services", "Weighted_Living_Environment"
        ]
    },
    "Parks_and_Housing": {
        "description": "Data related to parks and housing",
        "columns": [
            "Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m)",
            "Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2)",
            "Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius",
            "Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage)",
            "Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage)",
            "Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m)",
            "Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2)",
            "Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius",
            "Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage)",
            "Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage)",
            "Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space",
            "Weighted_Houses_Average_size_of_private_outdoor_space_(m2)",
            "Weighted_Houses_Median_size_of_private_outdoor_space_(m2)",
            "Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space",
            "Weighted_Flats_Average_size_of_private_outdoor_space_(m2)",
            "Weighted_Flats_Average_number_of_flats_sharing_a_garden",
            "Weighted_Total_Percentage_of_adresses_with_private_outdoor_space"
        ]
    },
    "Obesity": {
        "description": "Obesity-related data",
        "columns": [
            "Obesity_Prevalence(per_cent)"
        ]
    },
    "Smoking": {
        "description": "Smoking-related data",
        "columns": [
            "SMOK002(percent)",
            "SMOK004(percent)",
            "SMOK005(percent)"
        ]
    }
}

# %%
def SelectFeatures(df, feature_types, disease):
    Target = ""
    if disease == 'AST':
        Target = 'AST_Prevalence'
    elif disease == 'COPD':
        Target = 'COPD_Prevalence'
    else:
        print("Error: No matching case found for the disease provided.")
        return None
    
    print("Selected Categories :\n")
    selected_features = []
    

    for feature_type in feature_types:
        if feature_type in feature_categories:
            selected_features.extend(feature_categories[feature_type]["columns"])
            print(f"{feature_type}:")
            print(", ".join(feature_categories[feature_type]["columns"]))
            print(f"Description: {feature_categories[feature_type]['description']}\n")
        else:
            print(f"Error: Feature type '{feature_type}' not found!")

    selected_features_df = df[selected_features].copy()  # Make a copy of the selected features
    selected_features_df['YEAR'] = df['YEAR']
    selected_features_df[Target] = df[Target]
    
    # Remove rows where Target column has NaN values
    selected_features_df = selected_features_df.dropna(subset=[Target])

    return selected_features_df

# %% [markdown]
# ### בדיקה פנימית

# %%
SelectedCategories = ['COPD','Income', 'Smoking']
df_after_SelectFeatures = SelectFeatures(panel_06_df ,SelectedCategories , 'COPD' )
df_after_SelectFeatures.isnull().sum()
#df_after_SelectFeatures.info()
# Out:
# Selected Categories :
#
# COPD:
# COPD002(percent), COPD003(percent), COPD004(percent), COPD005(percent), COPD007(percent)
# Description: Chronic Obstructive Pulmonary Disease (COPD) related data
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
# COPD002(percent)                                       8064
# COPD003(percent)                                       8034
# COPD004(percent)                                       8034
# COPD005(percent)                                       8063
# COPD007(percent)                                       8033
# Weighted_Total_annual_income_(£)                        463
# Weighted_Net_annual_income_(£)                          463
# Weighted_Net_annual_income_before_housing_costs_(£)     463
# Weighted_Net_annual_income_after_housing_costs_(£)      463
# SMOK002(percent)                                       8120
# SMOK004(percent)                                       8128
# SMOK005(percent)                                       8138
# YEAR                                                      0
# COPD_Prevalence                                           0
# dtype: int64

# %% [markdown]
# ## פונקציה מספר 2 - ניקוי חריגים

# %% [markdown]
# ##### חדש

# %%
"""""#### מחודש
def OutliersRemoveOrReplace(df, method_outliers, threshold, action):
    """
   ''' Clean outliers from a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    method_outliers (str): The method to use for outlier detection ('IQR' or 'StdDev').
    threshold (float): The threshold for determining outliers.
    action (str): The action to take on outliers ('remove' or 'replace'). 
    
    Returns:
    pd.DataFrame: The DataFrame with outliers handled.''
    
    """
    
    if 'AST_Prevalence' in df.columns:
        Target = 'AST_Prevalence'
    elif 'COPD_Prevalence' in df.columns:
        Target = 'COPD_Prevalence'
    else:
        raise ValueError("No valid target column found.")
        
    print(Target)

    # Save the target column
    target_column = df[Target]

    # Remove the Target column for outlier detection
    df_without_target = df.drop(columns=[Target])

    # Select only numeric columns for outlier detection
    numeric_df = df_without_target.select_dtypes(include=[np.number])

    if method_outliers == 'IQR':
        Q1 = numeric_df.quantile(0.25)
        Q3 = numeric_df.quantile(0.75)
        IQR = Q3 - Q1
        filter_condition = ~((numeric_df < (Q1 - threshold * IQR)) | (numeric_df > (Q3 + threshold * IQR))).any(axis=1)
    elif method_outliers == 'StdDev':
        mean = numeric_df.mean()
        std_dev = numeric_df.std()
        filter_condition = ~((numeric_df < (mean - threshold * std_dev)) | (numeric_df > (mean + threshold * std_dev))).any(axis=1)
    else:
        raise ValueError("Invalid method. Choose 'IQR' or 'StdDev'.")

    if action == 'remove':
        # Filter the original dataframe to remove outliers
        df_clean = df[filter_condition].copy()
        
        print("Clean outliers method:", method_outliers)
        print("Threshold:", threshold)
        print("Action: remove outliers")
        print(f"Number of outliers removed: {len(df) - len(df_clean)}")
        print(f"Number of rows in the cleaned dataset: {len(df_clean)}\n")
        
        return df_clean
    
    elif action == 'replace':
        # Replace outliers with NaN
        df_replaced = df.copy()
        outlier_condition = (numeric_df < (mean - threshold * std_dev)) | (numeric_df > (mean + threshold * std_dev))
        df_replaced[outlier_condition] = np.nan
        
        print("Clean outliers method:", method_outliers)
        print("Threshold:", threshold)
        print("Action: replace outliers with NaN")
        print(f"Number of outliers replaced with NaN: {outlier_condition.sum().sum()}")
        
        # Reattach the Target column
        df_replaced[Target] = target_column.reset_index(drop=True)
        
        return df_replaced
    
    else:
        raise ValueError("Invalid action. Choose 'remove' or 'replace'.")"""""
# Out:
#   Cell In[23], line 4
#     ''' Clean outliers from a DataFrame.
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ##### ישן

# %%
####ישןןן

def OutliersRemoveOrReplace(df, method_outliers, threshold, action):
    """
    Clean outliers from a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    method_outliers (str): The method to use for outlier detection ('IQR' or 'StdDev').
    threshold (float): The threshold for determining outliers.
    action (str): The action to take on outliers ('remove' or 'replace'). 
    
    Returns:
    pd.DataFrame: The DataFrame with outliers handled.
    
    """
    
    if 'AST_Prevalence' in df.columns:
        Target = 'AST_Prevalence'
    elif 'COPD_Prevalence' in df.columns:
        Target = 'COPD_Prevalence'
        
    print(Target)
    # Select only numeric columns for outlier detection
    numeric_df = df.select_dtypes(include=[np.number])

    if method_outliers == 'IQR':
        Q1 = numeric_df.quantile(0.25)
        Q3 = numeric_df.quantile(0.75)
        IQR = Q3 - Q1
        filter_condition = ~((numeric_df < (Q1 - threshold * IQR)) | (numeric_df > (Q3 + threshold * IQR))).any(axis=1)
        outlier_condition = ((numeric_df < (Q1 - threshold * IQR)) | (numeric_df > (Q3 + threshold * IQR)))
    elif method_outliers == 'StdDev':
        mean = numeric_df.mean()
        std_dev = numeric_df.std()
        filter_condition = ~((numeric_df < (mean - threshold * std_dev)) | (numeric_df > (mean + threshold * std_dev))).any(axis=1)
        outlier_condition = ((numeric_df < (mean - threshold * std_dev)) | (numeric_df > (mean + threshold * std_dev)))
    else:
        raise ValueError("Invalid method. Choose 'IQR' or 'StdDev'.")

    if action == 'remove':
        # Filter the original dataframe to remove outliers
        df_clean = df[filter_condition]
        
        print("Clean outliers method:", method_outliers)
        print("Threshold:", threshold)
        print("Action: remove outliers")
        print(f"Number of outliers removed: {len(df) - len(df_clean)}")
        print(f"Number of rows in the cleaned dataset: {len(df_clean)}\n")
        
        return df_clean
    
    elif action == 'replace':
        # Replace outliers with NaN
        df_replaced = df.copy()
        df_replaced[outlier_condition] = np.nan


        
        print("Clean outliers method:", method_outliers)
        print("Threshold:", threshold)
        print("Action: replace outliers with NaN")
        print(f"Number of outliers replaced with NaN: {outlier_condition.sum().sum()}")
        

        return df_replaced
    
    else:
        raise ValueError("Invalid action. Choose 'remove' or 'replace'.")

# %% [markdown]
# ### בדיקה פנימית

# %%
method_outliers='IQR'
threshold = 2.5
Outliersaction='remove'
df_after_Clean_outliers = OutliersRemoveOrReplace(df_after_SelectFeatures, method_outliers, threshold, Outliersaction)
( df_after_SelectFeatures,method_outliers, threshold)
df_after_Clean_outliers.isnull().sum()
#df_after_Clean_outliers.info()
df_after_Clean_outliers
# Out:
# COPD_Prevalence
# Clean outliers method: IQR
# Threshold: 2.5
# Action: remove outliers
# Number of outliers removed: 8929
# Number of rows in the cleaned dataset: 43763
#        COPD002(percent)  COPD003(percent)  COPD004(percent)  COPD005(percent)  \
# 0                 92.59             96.88             94.74            100.00
# 2                 66.67            100.00            100.00            100.00
# 3                 83.93             96.34             92.59            100.00
# 4                 81.25             91.67             87.50            100.00
# 5                 86.00             90.00             91.04             97.14
# ...                 ...               ...               ...               ...
# 52697               NaN               NaN               NaN               NaN
# 52698               NaN               NaN               NaN               NaN
# 52699               NaN               NaN               NaN               NaN
# 52700               NaN               NaN               NaN               NaN
# 52701               NaN               NaN               NaN               NaN
#
#        COPD007(percent)  Weighted_Total_annual_income_(£)  \
# 0                100.00                           55044.0
# 2                100.00                           53602.0
# 3                 92.11                           61520.0
# 4                 93.48                           55607.0
# 5                100.00                           61166.0
# ...                 ...                               ...
# 52697               NaN                           45639.0
# 52698               NaN                           54229.0
# 52699               NaN                           50840.0
# 52700               NaN                           50825.0
# 52701               NaN                           41000.0
#
#        Weighted_Net_annual_income_(£)  \
# 0                             42671.0
# 2                             42084.0
# 3                             48162.0
# 4                             43442.0
# 5                             46834.0
# ...                               ...
# 52697                         39598.0
# 52698                         45323.0
# 52699                         43187.0
# 52700                         43712.0
# 52701                         33562.0
#
#        Weighted_Net_annual_income_before_housing_costs_(£)  \
# 0                                                37122.0
# 2                                                35591.0
# 3                                                37905.0
# 4                                                36950.0
# 5                                                39131.0
# ...                                                  ...
# 52697                                            35624.0
# 52698                                            39089.0
# 52699                                            38121.0
# 52700                                            37818.0
# 52701                                            33398.0
#
#        Weighted_Net_annual_income_after_housing_costs_(£)  SMOK002(percent)  \
# 0                                                31377.0          96.300000
# 2                                                30948.0          97.364568
# 3                                                35102.0          96.492986
# 4                                                31137.0          96.302521
# 5                                                33438.0          95.086442
# ...                                                  ...                ...
# 52697                                            33192.0                NaN
# 52698                                            34613.0                NaN
# 52699                                            34927.0                NaN
# 52700                                            34295.0                NaN
# 52701                                            29934.0                NaN
#
#        SMOK004(percent)  SMOK005(percent)  YEAR  COPD_Prevalence
# 0             90.300000         99.500000  2019             0.96
# 2             85.929648        100.000000  2019             0.22
# 3             91.026919         97.524752  2019             1.01
# 4             91.330798         98.657718  2019             0.55
# 5             81.818182         92.571429  2019             1.51
# ...                 ...               ...   ...              ...
# 52697               NaN               NaN  2013             1.43
# 52698               NaN               NaN  2013             1.15
# 52699               NaN               NaN  2013             1.34
# 52700               NaN               NaN  2013             1.38
# 52701               NaN               NaN  2013             1.72
#
# [43763 rows x 14 columns]

# %% [markdown]
# ### בדיקה של ערכים חריגים

# %%
Data_chek_outliers = {
    'Apple': np.array([100, 150, 10., 40., 60., 50., 60., 60., 50., 20., 100., 70., 40., 30., 100., 100., 60., 40., 10., 50.]),
    'Banana': np.array([50., 45., 2, 30., 15., 10., 45., 15., 15., 50., 15., 10., -15, 15., 10., 50., 500, 15., 100, 32]),
    'Cherry': np.array([100., 70., 30., 80., 70., 40., 40., 1000, 100., 15, 30., 100., 30., 10., 90., 40., 50., 70., 50, 30.]),
    'Pear': np.array([45., 55., 5., 35., 35., 35., 45., 35., 55., 25., 0, 45., 75., 25., 55., 15., 95., 75., 75., 45.]),
    'Elderberry': np.array([48., 84., 96., 48., 48., 24., 102., 96., 84., 108., 12., 60., 96., 36., 36., 60., 36., 72., 96., 72.])
}

df_chek_outliers = pd.DataFrame(Data_chek_outliers)
df_chek_outliers
# Out:
#     Apple  Banana  Cherry  Pear  Elderberry
# 0   100.0    50.0   100.0  45.0        48.0
# 1   150.0    45.0    70.0  55.0        84.0
# 2    10.0     2.0    30.0   5.0        96.0
# 3    40.0    30.0    80.0  35.0        48.0
# 4    60.0    15.0    70.0  35.0        48.0
# 5    50.0    10.0    40.0  35.0        24.0
# 6    60.0    45.0    40.0  45.0       102.0
# 7    60.0    15.0  1000.0  35.0        96.0
# 8    50.0    15.0   100.0  55.0        84.0
# 9    20.0    50.0    15.0  25.0       108.0
# 10  100.0    15.0    30.0   0.0        12.0
# 11   70.0    10.0   100.0  45.0        60.0
# 12   40.0   -15.0    30.0  75.0        96.0
# 13   30.0    15.0    10.0  25.0        36.0
# 14  100.0    10.0    90.0  55.0        36.0
# 15  100.0    50.0    40.0  15.0        60.0
# 16   60.0   500.0    50.0  95.0        36.0
# 17   40.0    15.0    70.0  75.0        72.0
# 18   10.0   100.0    50.0  75.0        96.0
# 19   50.0    32.0    30.0  45.0        72.0

# %%
"""הפונקציה calculate_outlier_bounds 
מקבלת דאטה פריים ומחזירה מילון שבו לכל עמודה יש גבולות עליונים ותחתונים לפי שיטת הזיהוי שנבחרה 
(IQR, Z-score או StdDev)."""

def calculate_outlier_bounds(df, method='IQR', threshold=1.5):
    outlier_bounds = {}
    
    for column in df.columns:
        data = df[column]
        
        if method == 'IQR':
            Q1 = data.quantile(0.25)
            Q3 = data.quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - threshold * IQR
            upper_bound = Q3 + threshold * IQR
        elif method == 'Z-score':
            z_scores = np.abs(stats.zscore(data))
            lower_bound = np.mean(data) - threshold * np.std(data)
            upper_bound = np.mean(data) + threshold * np.std(data)
        elif method == 'StdDev':
            mean = data.mean()
            std_dev = data.std()
            lower_bound = mean - threshold * std_dev
            upper_bound = mean + threshold * std_dev
        else:
            raise ValueError("Invalid method. Choose 'IQR', 'Z-score', or 'StdDev'.")
        
        outlier_bounds[column] = {'lower_bound': lower_bound, 'upper_bound': upper_bound}
    
    return outlier_bounds

# קריאה לפונקציה והדפסת התוצאות
outlier_bounds = calculate_outlier_bounds(df_chek_outliers)
for column, bounds in outlier_bounds.items():
    print(f"Column: {column}")
    print(f"Lower Bound: {bounds['lower_bound']}, Upper Bound: {bounds['upper_bound']}")
# Out:
# Column: Apple
# Lower Bound: -16.25, Upper Bound: 133.75
# Column: Banana
# Lower Bound: -35.0, Upper Bound: 95.0
# Column: Cherry
# Lower Bound: -48.75, Upper Bound: 161.25
# Column: Pear
# Lower Bound: -1.25, Upper Bound: 88.75
# Column: Elderberry
# Lower Bound: -31.5, Upper Bound: 172.5

# %%
df_after_chek_outliers= OutliersRemoveOrReplace(df_chek_outliers, method_outliers, threshold, Outliersaction)
df_after_chek_outliers
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_after_chek_outliers= OutliersRemoveOrReplace(df_chek_outliers, method_outliers, threshold, Outliersaction)
#       2 df_after_chek_outliers
#
# Cell In[26], line 23, in OutliersRemoveOrReplace(df, method_outliers, threshold, action)
#      20 elif 'COPD_Prevalence' in df.columns:
#      21     Target = 'COPD_Prevalence'
# ---> 23 print(Target)
#      24 # Select only numeric columns for outlier detection
#      25 numeric_df = df.select_dtypes(include=[np.number])
#
# UnboundLocalError: cannot access local variable 'Target' where it is not associated with a value

# %% [markdown]
# ## פונקציה מספר 3 - השלמת חסרים

# %%
def Fill_missing_values(df, method_missing_values):
        
    # Count initial missing values
    initial_missing_count = df.isnull().sum().sum()
    
    if method_missing_values == 'mean':
        df_filled = df.fillna(df.mean())
    elif method_missing_values == 'median':
        df_filled = df.fillna(df.median())
    elif method_missing_values == 'drop_rows':
        df_filled = df.dropna()
    else:
        raise ValueError("Invalid method. Choose 'mean', 'median', or 'drop_rows'.")

    # Count remaining missing values
    remaining_missing_count = df_filled.isnull().sum().sum()

    # Calculate number of missing values handled
    num_filled = initial_missing_count - remaining_missing_count

    print("missing values method:", method_missing_values)
    print(f"Number of missing values handled: {num_filled}")
    print(f"Number of remaining missing values: {remaining_missing_count}")
    PercentageOfHandel = num_filled / df.size * 100
    if method_missing_values == 'drop_rows':
        print(f"Number of remaining rows: {df_filled.shape[0]}")
    print(f"Percentage of values handled: {PercentageOfHandel:.2f}%\n")

 

    return df_filled, num_filled, PercentageOfHandel

# %% [markdown]
# ### בדיקה פנימית

# %%
method_missing_values='mean'
df_after_Fill_missing_values, num_filled, PercentageOfHandel = Fill_missing_values(df_after_Clean_outliers, method_missing_values)
df_after_Fill_missing_values.isnull().sum()
# Out:
# missing values method: mean
# Number of missing values handled: 65547
# Number of remaining missing values: 0
# Percentage of values handled: 10.70%
# COPD002(percent)                                       0
# COPD003(percent)                                       0
# COPD004(percent)                                       0
# COPD005(percent)                                       0
# COPD007(percent)                                       0
# Weighted_Total_annual_income_(£)                       0
# Weighted_Net_annual_income_(£)                         0
# Weighted_Net_annual_income_before_housing_costs_(£)    0
# Weighted_Net_annual_income_after_housing_costs_(£)     0
# SMOK002(percent)                                       0
# SMOK004(percent)                                       0
# SMOK005(percent)                                       0
# YEAR                                                   0
# COPD_Prevalence                                        0
# dtype: int64

# %% [markdown]
# ### בדיקה של השלמת חוסרים

# %%
# Setting the seed for reproducibility
np.random.seed(50)

# Creating a DataFrame with 5 columns and 10 rows with some missing values
data_chek_missing = {
    'Apple': np.random.choice([np.nan, *range(10, 110, 10)], 20),
    'Banana': np.random.choice([np.nan, *range(5, 55, 5)], 20),
    'Cherry': np.random.choice([np.nan, *range(10, 110, 10)], 20),
    'Pear': np.random.choice([np.nan, *range(5, 105, 10)], 20),
    'Elderberry': np.random.choice([np.nan, *range(12, 120, 12)], 20)
}


df_chek_missing = pd.DataFrame(data_chek_missing)
df_chek_missing
# Out:
#     Apple  Banana  Cherry  Pear  Elderberry
# 0     NaN    50.0   100.0  45.0        48.0
# 1     NaN    45.0    70.0  55.0        84.0
# 2    10.0     NaN    30.0   5.0        96.0
# 3    40.0    30.0    80.0  35.0        48.0
# 4    60.0    15.0    70.0  35.0        48.0
# 5    50.0    10.0    40.0  35.0        24.0
# 6    60.0    45.0    40.0  45.0        12.0
# 7    60.0    15.0     NaN  35.0        96.0
# 8    50.0    15.0   100.0  55.0        84.0
# 9    20.0    50.0     NaN  25.0       108.0
# 10  100.0    15.0    30.0   NaN        12.0
# 11   70.0    10.0   100.0  45.0        60.0
# 12   40.0     NaN    30.0  75.0        96.0
# 13   30.0    15.0    10.0  25.0        36.0
# 14  100.0    10.0    90.0  55.0        36.0
# 15  100.0    50.0    40.0  15.0        60.0
# 16   60.0     NaN    50.0  95.0        36.0
# 17   40.0    15.0    70.0  75.0        72.0
# 18   10.0     NaN     NaN  75.0        96.0
# 19   50.0     NaN    30.0  45.0        72.0

# %%
mean_values = df_chek_missing.mean()
print("\nMean values of each product:")
print(mean_values)

df_chek_missing.isnull().sum()
# Out:
# Mean values of each product:
# Apple         52.777778
# Banana        26.000000
# Cherry        57.647059
# Pear          46.052632
# Elderberry    61.200000
# dtype: float64
# Apple         2
# Banana        5
# Cherry        3
# Pear          1
# Elderberry    0
# dtype: int64

# %%
df_after_chek_missing, w, z = Fill_missing_values(df_chek_missing, method_missing_values)
print(df_after_chek_missing)
# Out:
# missing values method: mean
# Number of missing values handled: 11
# Number of remaining missing values: 0
# Percentage of values handled: 11.00%
#
#          Apple  Banana      Cherry       Pear  Elderberry
# 0    52.777778    50.0  100.000000  45.000000        48.0
# 1    52.777778    45.0   70.000000  55.000000        84.0
# 2    10.000000    26.0   30.000000   5.000000        96.0
# 3    40.000000    30.0   80.000000  35.000000        48.0
# 4    60.000000    15.0   70.000000  35.000000        48.0
# 5    50.000000    10.0   40.000000  35.000000        24.0
# 6    60.000000    45.0   40.000000  45.000000        12.0
# 7    60.000000    15.0   57.647059  35.000000        96.0
# 8    50.000000    15.0  100.000000  55.000000        84.0
# 9    20.000000    50.0   57.647059  25.000000       108.0
# 10  100.000000    15.0   30.000000  46.052632        12.0
# 11   70.000000    10.0  100.000000  45.000000        60.0
# 12   40.000000    26.0   30.000000  75.000000        96.0
# 13   30.000000    15.0   10.000000  25.000000        36.0
# 14  100.000000    10.0   90.000000  55.000000        36.0
# 15  100.000000    50.0   40.000000  15.000000        60.0
# 16   60.000000    26.0   50.000000  95.000000        36.0
# 17   40.000000    15.0   70.000000  75.000000        72.0
# 18   10.000000    26.0   57.647059  75.000000        96.0
# 19   50.000000    26.0   30.000000  45.000000        72.0

# %% [markdown]
# ## פונקציה מספר 4 - ולידאציה של היפר פרמטים

# %%
def safe_map(func, value_str):
    if value_str.strip('[]'):
        return list(map(func, value_str.strip('[]').split(',')))
    else:
        return []

# %% [markdown]
# ## פונקציה מספר 5 - סינון שורות לפי שנים

# %%
def FilterByYears(df, years):
    # בדיקת קיום עמודת השנה
    if 'YEAR' not in df.columns:
        print("Error: 'YEAR' column does not exist in DataFrame")
        return None
    
    # המרת years לרשימה אם זה לא רשימה כבר
    if not isinstance(years, list):
        years = [years]
    
    df['YEAR'] = df['YEAR'].astype(str).str.strip()
    df = df[df['YEAR'].str.isnumeric()]
    
    available_years = set(df['YEAR'].unique())
    missing_years = [year for year in years if year not in available_years]
    
    if missing_years:
        print(f"Warning: The following years are not available in the DataFrame: {missing_years}")
    
    # סינון ה-DataFrame לפי השנים שהתקבלו
    filtered_df = df[df['YEAR'].isin(years)].copy()
    filtered_df['YEAR'] = filtered_df['YEAR'].astype(int)
    print(f"Years selected for filtering: {years}")
    return filtered_df

# %% [markdown]
# ### בדיקה פנימית

# %%
years_to_filter = ['2014','2015','2016']
type(years_to_filter)
print(years_to_filter)
# Out:
# ['2014', '2015', '2016']

# %%
after_FilterByYears_df = FilterByYears(df_after_Fill_missing_values, years_to_filter)
# Out:
# Years selected for filtering: ['2014', '2015', '2016']

# %%
unique_years = after_FilterByYears_df['YEAR'].unique()
print(unique_years)
after_FilterByYears_df.head(2)
# Out:
# [2016 2015 2014]
#        COPD002(percent)  COPD003(percent)  COPD004(percent)  COPD005(percent)  \
# 21365             92.56             91.03             85.24             93.33
# 21366             97.78             94.09             92.04             94.44
#
#        COPD007(percent)  Weighted_Total_annual_income_(£)  \
# 21365             98.65                           37497.0
# 21366             99.57                           39612.0
#
#        Weighted_Net_annual_income_(£)  \
# 21365                         29547.0
# 21366                         30570.0
#
#        Weighted_Net_annual_income_before_housing_costs_(£)  \
# 21365                                            28444.0
# 21366                                            29074.0
#
#        Weighted_Net_annual_income_after_housing_costs_(£)  SMOK002(percent)  \
# 21365                                            27527.0          98.009243
# 21366                                            27198.0          97.457344
#
#        SMOK004(percent)  SMOK005(percent)  YEAR  COPD_Prevalence
# 21365         74.574347         97.510373  2016             2.72
# 21366         91.800981         97.820163  2016             2.40

# %% [markdown]
# ## פונקציה מספר 6  - נרמול ערכים

# %%
def Normalize_data(df, normalize_method):
    
    if normalize_method == 'Min-Max':
        scaler = MinMaxScaler()
        print("Normalization method: Min-Max\n")
    elif normalize_method == 'Quartile':
        print("Normalization method: Quartile\n")
        scaler = None
    else:
        print("Invalid normalization method. Choose 'Min-Max' or 'Quartile'.")
        return df
    
    # הפרדת העמודה האחרונה
    last_column = df.iloc[:, -1]
    columns_to_normalize = df.iloc[:, :-1]
    
    if normalize_method == 'Min-Max':
        # נרמול העמודות מלבד העמודה האחרונה
        normalized_data = pd.DataFrame(scaler.fit_transform(columns_to_normalize), columns=columns_to_normalize.columns)
    elif normalize_method == 'Quartile':
        # חישוב רבעונים
        Q1 = columns_to_normalize.quantile(0.25)
        Q3 = columns_to_normalize.quantile(0.75)
        IQR = Q3 - Q1
        normalized_data = (columns_to_normalize - Q1) / IQR
    
    # הוספת העמודה האחרונה חזרה ל-DataFrame
    normalized_data = pd.concat([normalized_data, last_column.reset_index(drop=True)], axis=1)
       
    return normalized_data

# %% [markdown]
# ### בדיקה פנימית

# %%
#בדיקה פנימית
normalize_method  = 'Min-Max'
normalize_method  = 'Quartile'
df_after_Normalize_data = Normalize_data(after_FilterByYears_df, normalize_method)
df_after_Normalize_data.head(3)
# Out:
# Normalization method: Quartile
#        COPD002(percent)  COPD003(percent)  COPD004(percent)  COPD005(percent)  \
# 21365          0.574747         -0.027907         -0.096203         -0.244403
# 21366          1.102020          0.683721          0.764557         -0.037313
# 21367          0.493939          0.572093          0.418987          0.779851
#
#        COPD007(percent)  Weighted_Total_annual_income_(£)  \
# 21365          0.410480                          0.289795
# 21366          0.812227                          0.465416
# 21367          0.646288                          0.447646
#
#        Weighted_Net_annual_income_(£)  \
# 21365                        0.249367
# 21366                        0.359669
# 21367                        0.357189
#
#        Weighted_Net_annual_income_before_housing_costs_(£)  \
# 21365                                           0.365097
# 21366                                           0.449474
# 21367                                           0.443180
#
#        Weighted_Net_annual_income_after_housing_costs_(£)  SMOK002(percent)  \
# 21365                                           0.739484           1.195609
# 21366                                           0.691761           1.022709
# 21367                                           0.712649           0.075576
#
#        SMOK004(percent)  SMOK005(percent)  YEAR  COPD_Prevalence
# 21365         -1.182878          0.307864   1.0              NaN
# 21366          0.614349          0.420904   1.0              NaN
# 21367          0.686366          0.973051   1.0              NaN

# %% [markdown]
# ## XY פונקציה מספר 7 - פיצול סט מבחן וחלוקה ל

# %%
def SplitDataAndPrepForModel(df, test_size=0.2 ):
    
    columns_to_drop = ['YEAR']
    
    df_after_drop = df.drop(columns=columns_to_drop)
    # Shuffle the DataFrame
    df_shuffled = shuffle(df_after_drop, random_state=42)

    X = df_shuffled.iloc[:, :-1] # הסרת העמודה האחרונה
    y = df_shuffled.iloc[:, -1]  # בחירת העמודה האחרונה  

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)


    return X_train, X_test, y_train, y_test

# %% [markdown]
# בדיקה פנימית

# %%
X_train, X_test, y_train, y_test = SplitDataAndPrepForModel(df_after_Normalize_data, test_size=0.2)

# %% [markdown]
# ## פונקציה 8 - אימון וולדיצה של המודל

# %%
def train_and_evaluate_model(X_train, X_test, y_train, y_test, param_grid, model_name, expriment_number, cv=3):
    if model_name == 'random_forest':
        model = RandomForestRegressor()
    elif model_name == 'linear_regression':
        model = LinearRegression()
    elif model_name == 'xgboost':
        model = XGBRegressor()
    else:
        raise ValueError(f"Unsupported model: {model_name}")
    
    print("model_name:", model_name)
    print("cv:", cv)

    grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='neg_mean_squared_error')
    grid_search.fit(X_train, y_train)

    best_model = grid_search.best_estimator_

    # Get cross-validation scores
    scores = cross_val_score(best_model, X_train, y_train, cv=cv, scoring='neg_mean_squared_error')
    mean_score = scores.mean()
    std_score = scores.std()  # Standard deviation of the cross-validation scores
    rmse_score = np.sqrt(-scores)  # RMSE for each fold in cross-validation

    # Evaluate on test data
    r_squared = best_model.score(X_test, y_test)  # R^2 on test data
    y_pred = best_model.predict(X_test)
    mse_test = mean_squared_error(y_test, y_pred)
    mae_test = mean_absolute_error(y_test, y_pred)
    rmse_test = np.sqrt(mse_test)  # RMSE on test data
    std_test = np.std(y_pred)  # Standard deviation of the test predictions
    
    print("best_model:", best_model)
    print("best_params:", best_model.get_params())
    print("cross_val_scores:", scores)
    print("mean_cross_val_score:", mean_score)
    print("std_cross_val_score:", std_score)
    print("mean_cross_val_rmse:", rmse_score.mean())
    print("r2_score:", r_squared)
    print("mean_squared_error_test:", mse_test)
    print("mean_absolute_error_test:", mae_test)
    print("root_mean_squared_error_test:", rmse_test)
    print("std_test:", std_test)
    
    results = {
        'best_model': best_model,
        'cross_val_scores': scores,
        'mean_cross_val_score': mean_score,
        'std_cross_val_score': std_score,
        'mean_cross_val_rmse': rmse_score.mean(),
        'r_squared': r_squared,
        'best_params': best_model.get_params(),
        'mse_test': mse_test,
        'mae_test': mae_test,
        'rmse_test': rmse_test,
        'std_test': std_test
    }
    
    # Save the best model using pickle
    output_path = './outputData/'
    model_filename = f'Output_ExperimentNumber{expriment_number}.pkl'
    model_filepath = os.path.join(output_path, model_filename)
    with open(model_filepath, 'wb') as f:
        pickle.dump(best_model, f)
    
    return results

# %% [markdown]
# ## פונקציה מספר 9 - יוצרת גריד פרמטרים

# %%
def get_param_grid(model_name, model_params):
    param_grid = {}
    
    if model_name == 'random_forest':
        param_grid = {key: model_params[key] for key in model_params.keys() & {'n_estimators', 'max_depth', 'min_samples_split', 'min_samples_leaf'}}
    elif model_name == 'linear_regression':
        param_grid = {}
    elif model_name == 'xgboost':
        param_grid = {key: model_params[key] for key in model_params.keys() & {'n_estimators', 'max_depth', 'learning_rate', 'colsample_bytree', 'reg_lambda'}}
    else:
        raise ValueError(f"Unsupported model: {model_name}")
        
    print('The param grid for '+model_name+ ' model is:\n' )
    print(param_grid)


    return param_grid

# %% [markdown]
# ## פונקציה 10 -  יוצרת פאנל, מפעילה את כל שאר הפונקציות

# %%
# מהופכת את הפאנל ,  להיות מוכן למודל

def Make_final_panel (panel_path,disease ,feature_types,method_outliers,threshold,Outliersaction,method_missing_values,normalize_method,years):
    
    OG_panel_df = pd.read_csv(panel_path)       
    after_FilterByYears_df = FilterByYears(OG_panel_df,years)
    after_selectFeatures_df = SelectFeatures(after_FilterByYears_df, feature_types, disease)
    after_CleanOutliers_df = OutliersRemoveOrReplace( after_selectFeatures_df , method_outliers, threshold,Outliersaction)
    after_missingValues_df,num_filled, remaining_missing_count = Fill_missing_values(after_CleanOutliers_df, method_missing_values)
    after_NormalizeData_df = Normalize_data(after_missingValues_df, normalize_method)
    
    return after_NormalizeData_df

# %% [markdown]
# # פונקציה סופית

# %%
# הפונקציה הראשית שמבצעת את כל הניסויים
def Final_fun(file_path_of_params, panel_path):
    
    # קריאת קובץ האקסל המכיל את פרמטרי הניסויים
    ExprimentTracker_df = pd.read_excel(file_path_of_params, keep_default_na=False,skiprows = 8 )
    
   
    # יצירת DataFrame ריק עם כותרות מתאימות
    all_results = pd.DataFrame(columns=['ExperimentNumber'] + list(ExprimentTracker_df.columns))



    # קריאת תוצאות קיימות אם הקובץ קיים
 #   if os.path.exists(results_filename):
  #      all_results = pd.read_excel(results_filename)
    
    # מעבר על כל שורה בקובץ האקסל של פרמטרי הניסויים
    for index, row in ExprimentTracker_df.iterrows():
        
        
        # שליפת פרטי הניסוי הנוכחי
        experiment_number = int(row['ExperimentNumber'])  # מספר הניסוי
        years = row['Years'].split(', ')  # השנים הנכללות בניסוי
        target = row['target']  # מטרה
        feature_types = row['feature_types'].split(', ')  # סוגי מאפיינים
        method_outliers = row['method_outliers']  # שיטת טיפול בנקודות חריגות
        Outliersaction = row['Outliersaction'] # מחיקה של שורה או לשים ערך ריק
        threshold = row['threshold']  # סף
        method_missing_values = row['method_missing_values']  # שיטת טיפול בערכים חסרים
        normalize_method = row['normalize_method']  # שיטת נורמליזציה
        model_name = row['model_name']  # שם המודל
        n_estimators = safe_map(int, str(row['n_estimators']))  # מספר האסימאטורים
        max_depth = safe_map(int, str(row['max_depth']))  # עומק מקסימלי
        learning_rate = safe_map(float, str(row['learning_rate']))  # שיעור למידה
        min_samples_split = safe_map(int, str(row['min_samples_split']))  # מינימום דוגמאות לפיצול
        min_samples_leaf = safe_map(int, str(row['min_samples_leaf']))  # מינימום דוגמאות בעלה
        colsample_bytree = safe_map(float, str(row['colsample_bytree']))  # דגימה לפי עץ
        reg_lambda = safe_map(float, str(row['reg_lambda']))  # פרמטר רגולריזציה
        cv = int(row['cv'])  # קרוס ולידציה
        
        # הדפסת מידע על הניסוי הנוכחי
        print('\n', 25*"#", " Experiment Number ", experiment_number, 25*"#")

        # יצירת הפאנל הסופי על פי הפרמטרים
        final_panel = Make_final_panel(panel_path, target, feature_types, method_outliers, threshold,Outliersaction, method_missing_values, normalize_method, years)

        # חלוקת הנתונים לערכות אימון ובדיקה
        X_train, X_test, y_train, y_test = SplitDataAndPrepForModel(final_panel, test_size=0.2)
        
        # הגדרת פרמטרי המודל
        model_params = {
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'learning_rate': learning_rate,
            'min_samples_split': min_samples_split,
            'min_samples_leaf': min_samples_leaf,
            'colsample_bytree': colsample_bytree,
            'reg_lambda': reg_lambda,
        }
        
        # יצירת גריד של פרמטרים למודל
        param_grid = get_param_grid(model_name, model_params)
        
        start_time = time.time()
        
        # אימון והערכת המודל
        results = train_and_evaluate_model(X_train, X_test, y_train, y_test, param_grid, model_name,  experiment_number,cv)
        
        end_time = time.time()
        total_time_seconds = end_time - start_time
        total_time_minutes = total_time_seconds / 60  # Convert seconds to minutes
        
        # וידוא שהתוצאות הן מילון
        if not isinstance(results, dict):
            raise ValueError("The results from train_and_evaluate_model should be a dictionary")

        # יצירת שורת נתונים חדשה עם תוצאות הניסוי
        new_row = row.to_dict()
        new_row.update(results)
        new_row['date_time'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        new_row['RunTimeMinutes'] = total_time_minutes        
        new_row['num_columns'] = (final_panel.shape[1]-1)
        new_row['num_rows'] = final_panel.shape[0]
      
        new_row_df = pd.DataFrame([new_row])
        print("Running time in minutes  : ",total_time_minutes  )
        
        # וידוא שהעמודות ייחודיות
        all_results = all_results.loc[:,~all_results.columns.duplicated()]
        new_row_df = new_row_df.loc[:,~new_row_df.columns.duplicated()]

        # בדיקת עמודות חסרות והוספת ערכי None
        missing_cols = set(all_results.columns) - set(new_row_df.columns)
        for col in missing_cols:
            new_row_df[col] = None
        
        # הוספת השורה החדשה ל-DataFrame של כל התוצאות
        all_results = pd.concat([all_results, new_row_df], ignore_index=True)
        
            # שם הקובץ לשמירת התוצאות
        results_filename = "Output_ExprimentResults_"+model_name+".xlsx"
        
        # שמירת התוצאות לקובץ אקסל
        all_results.to_excel(results_filename, index=False)
        #all_results.info()

              
    return all_results

# %% [markdown]
# # הרצה של פונקציה סופית

# %%
panel_path = 'InputData\Panel_06.csv'
ExprimentTracker_path ='InputData\‏‏‏‏ExprimentTracker_LinearRegression_BigTreashold.xlsx'
test = Final_fun (ExprimentTracker_path,panel_path)
# Out:
#  #########################  Experiment Number  1 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 320
# Number of remaining missing values: 0
# Percentage of values handled: 0.14%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.8170597  -1.82563422 -1.83627917]
# mean_cross_val_score: -1.826324364236242
# std_cross_val_score: 0.007861473579091708
# mean_cross_val_rmse: 1.3514125597184465
# r2_score: 0.029284324947255858
# mean_squared_error_test: 1.7843361802948536
# mean_absolute_error_test: 1.0315240696355414
# root_mean_squared_error_test: 1.3357904702066314
# std_test: 0.21058711661917273
# Running time in minutes  :  0.0022188345591227215
#
#  #########################  Experiment Number  2 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 380
# Number of rows in the cleaned dataset: 44301
#
# missing values method: mean
# Number of missing values handled: 3894
# Number of remaining missing values: 0
# Percentage of values handled: 0.21%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.52224133e+00 -5.86861232e+05 -1.43373948e+00]
# mean_cross_val_score: -195621.3960316611
# std_cross_val_score: 276648.3411642587
# mean_cross_val_rmse: 256.16662211485493
# r2_score: 0.20556982352512632
# mean_squared_error_test: 1.4225457697689496
# mean_absolute_error_test: 0.9036740518481317
# root_mean_squared_error_test: 1.1927052317186126
# std_test: 0.610460374675028
# Running time in minutes  :  0.0030980984369913737
#
#  #########################  Experiment Number  3 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 1024
# Number of remaining missing values: 0
# Percentage of values handled: 0.38%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.41726083 -1.44098679 -1.41275753]
# mean_cross_val_score: -1.4236683813965854
# std_cross_val_score: 0.012383195639385015
# mean_cross_val_rmse: 1.1931645015285397
# r2_score: 0.2507780598410406
# mean_squared_error_test: 1.377194011854911
# mean_absolute_error_test: 0.8828443347619074
# root_mean_squared_error_test: 1.1735390968582644
# std_test: 0.6695783934191031
# Running time in minutes  :  0.0006501396497090657
#
#  #########################  Experiment Number  4 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 2048
# Number of remaining missing values: 0
# Percentage of values handled: 0.46%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.40413944 -1.40777803 -1.3846393 ]
# mean_cross_val_score: -1.3988522584578709
# std_cross_val_score: 0.010159263341930633
# mean_cross_val_rmse: 1.182723031661026
# r2_score: 0.26487892436176985
# mean_squared_error_test: 1.3512742874861807
# mean_absolute_error_test: 0.8747494173708714
# root_mean_squared_error_test: 1.1624432405438903
# std_test: 0.6987905060689757
# Running time in minutes  :  0.0009089310963948568
#
#  #########################  Experiment Number  5 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1078
# Number of rows in the cleaned dataset: 43603
#
# missing values method: mean
# Number of missing values handled: 4352
# Number of remaining missing values: 0
# Percentage of values handled: 0.53%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.45113928 -1.52918132 -1.43602946]
# mean_cross_val_score: -1.4721166863426465
# std_cross_val_score: 0.040819569748740264
# mean_cross_val_rmse: 1.2131925342780872
# r2_score: 0.2142488706154545
# mean_squared_error_test: 1.4660594492338814
# mean_absolute_error_test: 0.9167033359079381
# root_mean_squared_error_test: 1.2108094190391325
# std_test: 0.6072754213895043
# Running time in minutes  :  0.0016938845316569011
#
#  #########################  Experiment Number  6 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 106
# Number of remaining missing values: 0
# Percentage of values handled: 0.08%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.67652166 -1.68381366 -1.66998595]
# mean_cross_val_score: -1.6767737569153693
# std_cross_val_score: 0.005647953043589158
# mean_cross_val_rmse: 1.2949011550558476
# r2_score: 0.10374139131433335
# mean_squared_error_test: 1.647471760762149
# mean_absolute_error_test: 0.9928803813070515
# root_mean_squared_error_test: 1.2835387648069492
# std_test: 0.4423902581232538
# Running time in minutes  :  0.0006010293960571289
#
#  #########################  Experiment Number  7 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 554
# Number of rows in the cleaned dataset: 44127
#
# missing values method: mean
# Number of missing values handled: 322
# Number of remaining missing values: 0
# Percentage of values handled: 0.15%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.87004017 -1.82235416 -1.8342265 ]
# mean_cross_val_score: -1.8422069437642046
# std_cross_val_score: 0.020269095918550223
# mean_cross_val_rmse: 1.3572587631665713
# r2_score: 0.005485128672507167
# mean_squared_error_test: 1.8307346878490933
# mean_absolute_error_test: 1.033679507107249
# root_mean_squared_error_test: 1.3530464470405639
# std_test: 0.0864917554188707
# Running time in minutes  :  0.0006543715794881185
#
#  #########################  Experiment Number  8 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 380
# Number of rows in the cleaned dataset: 44301
#
# missing values method: mean
# Number of missing values handled: 4214
# Number of remaining missing values: 0
# Percentage of values handled: 0.22%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.49392797e+00 -5.62998966e+05 -1.41408156e+00]
# mean_cross_val_score: -187667.2912940974
# std_cross_val_score: 265399.5722886777
# mean_cross_val_rmse: 250.9146617518844
# r2_score: 0.2121052679694455
# mean_squared_error_test: 1.4108430813223958
# mean_absolute_error_test: 0.9008867484241667
# root_mean_squared_error_test: 1.1877891569308063
# std_test: 0.6300689635179634
# Running time in minutes  :  0.003066543738047282
#
#  #########################  Experiment Number  9 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 1344
# Number of remaining missing values: 0
# Percentage of values handled: 0.33%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.39166785 -1.42054891 -1.3946393 ]
# mean_cross_val_score: -1.402285353278354
# std_cross_val_score: 0.012971137319946913
# mean_cross_val_rmse: 1.1841686749546025
# r2_score: 0.26513381552839654
# mean_squared_error_test: 1.3508057553069464
# mean_absolute_error_test: 0.875213200720423
# root_mean_squared_error_test: 1.1622416940150384
# std_test: 0.6880840324553975
# Running time in minutes  :  0.0008762955665588378
#
#  #########################  Experiment Number  10 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 2368
# Number of remaining missing values: 0
# Percentage of values handled: 0.41%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.37893135 -1.38750816 -1.36764762]
# mean_cross_val_score: -1.37802904643121
# std_cross_val_score: 0.008133096884701232
# mean_cross_val_rmse: 1.1738897052436286
# r2_score: 0.27875904352498626
# mean_squared_error_test: 1.3257603296443181
# mean_absolute_error_test: 0.8669510770985506
# root_mean_squared_error_test: 1.1514166620491115
# std_test: 0.71573614986205
# Running time in minutes  :  0.0011413892110188801
#
#  #########################  Experiment Number  11 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1078
# Number of rows in the cleaned dataset: 43603
#
# missing values method: mean
# Number of missing values handled: 4667
# Number of remaining missing values: 0
# Percentage of values handled: 0.49%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.42690145 -1.50680312 -1.41694224]
# mean_cross_val_score: -1.450215601537905
# std_cross_val_score: 0.04021945206745495
# mean_cross_val_rmse: 1.204134240648057
# r2_score: 0.22303512171718332
# mean_squared_error_test: 1.449666006107531
# mean_absolute_error_test: 0.9106734547351617
# root_mean_squared_error_test: 1.2040207664768623
# std_test: 0.6221344473013773
# Running time in minutes  :  0.0016630013783772786
#
#  #########################  Experiment Number  12 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 426
# Number of remaining missing values: 0
# Percentage of values handled: 0.16%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.64298214 -1.65202432 -1.64105473]
# mean_cross_val_score: -1.6453537303253685
# std_cross_val_score: 0.004781998150057934
# mean_cross_val_rmse: 1.2827120717043015
# r2_score: 0.12654937315933656
# mean_squared_error_test: 1.6055469126820598
# mean_absolute_error_test: 0.9769460551372603
# root_mean_squared_error_test: 1.2671017767654105
# std_test: 0.47525838500918316
# Running time in minutes  :  0.0007081826527913412
#
#  #########################  Experiment Number  13 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Asthma:
# AST002(percent), AST003(percent), AST004(percent)
# Description: Asthma-related data
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 554
# Number of rows in the cleaned dataset: 44127
#
# missing values method: mean
# Number of missing values handled: 621
# Number of remaining missing values: 0
# Percentage of values handled: 0.18%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.81600713 -1.78523712 -1.79204055]
# mean_cross_val_score: -1.797761600424871
# std_cross_val_score: 0.01319712445403531
# mean_cross_val_rmse: 1.3407973116339953
# r2_score: 0.029164650391755975
# mean_squared_error_test: 1.7871446691847777
# mean_absolute_error_test: 1.0204694406956165
# root_mean_squared_error_test: 1.3368413029169834
# std_test: 0.22603430347964532
# Running time in minutes  :  0.0008449157079060873
#
#  #########################  Experiment Number  14 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 380
# Number of rows in the cleaned dataset: 44301
#
# missing values method: mean
# Number of missing values handled: 4902
# Number of remaining missing values: 0
# Percentage of values handled: 0.25%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.34327504e+00 -5.95697076e+05 -1.27815510e+00]
# mean_cross_val_score: -198566.56586501215
# std_cross_val_score: 280813.676849123
# mean_cross_val_rmse: 258.0345662586007
# r2_score: 0.29904586831444946
# mean_squared_error_test: 1.2551629637936905
# mean_absolute_error_test: 0.8422257141216172
# root_mean_squared_error_test: 1.1203405570600802
# std_test: 0.7411466035885463
# Running time in minutes  :  0.0030752102533976237
#
#  #########################  Experiment Number  15 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 380
# Number of rows in the cleaned dataset: 44301
#
# missing values method: mean
# Number of missing values handled: 5910
# Number of remaining missing values: 0
# Percentage of values handled: 0.27%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.34121173e+00 -5.96623288e+05 -1.26057554e+00]
# mean_cross_val_score: -198875.29669490713
# std_cross_val_score: 281250.30206549016
# mean_cross_val_rmse: 258.2315987880563
# r2_score: 0.3000822152475302
# mean_squared_error_test: 1.253307229974252
# mean_absolute_error_test: 0.8429686099767765
# root_mean_squared_error_test: 1.1195120499459807
# std_test: 0.7456139508750169
# Running time in minutes  :  0.00314179261525472
#
#  #########################  Experiment Number  16 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1445
# Number of rows in the cleaned dataset: 43236
#
# missing values method: mean
# Number of missing values handled: 8139
# Number of remaining missing values: 0
# Percentage of values handled: 0.32%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.35846631e+00 -1.37793694e+00 -1.11446470e+06]
# mean_cross_val_score: -371489.147061164
# std_cross_val_score: 525363.0551190174
# mean_cross_val_rmse: 352.6738307506351
# r2_score: 0.25280645392048096
# mean_squared_error_test: 1.3769173908211532
# mean_absolute_error_test: 0.874333540138536
# root_mean_squared_error_test: 1.173421233326359
# std_test: 0.6739147760713157
# Running time in minutes  :  0.004288419087727865
#
#  #########################  Experiment Number  17 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 380
# Number of rows in the cleaned dataset: 44301
#
# missing values method: mean
# Number of missing values handled: 4000
# Number of remaining missing values: 0
# Percentage of values handled: 0.21%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.44383981e+00 -5.80491784e+05 -1.35810685e+00]
# mean_cross_val_score: -193498.19515260914
# std_cross_val_score: 273645.7906040535
# mean_cross_val_rmse: 254.7556970461403
# r2_score: 0.2509237764501865
# mean_squared_error_test: 1.3413327496868945
# mean_absolute_error_test: 0.8774710279617712
# root_mean_squared_error_test: 1.1581592074006468
# std_test: 0.672950596196938
# Running time in minutes  :  0.00288923184076945
#
#  #########################  Experiment Number  18 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 927
# Number of rows in the cleaned dataset: 43754
#
# missing values method: mean
# Number of missing values handled: 4023
# Number of remaining missing values: 0
# Percentage of values handled: 0.21%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.52679765 -1.37961372 -1.42574875]
# mean_cross_val_score: -1.4440533738443122
# std_cross_val_score: 0.06146582612525586
# mean_cross_val_rmse: 1.2014177801921668
# r2_score: 0.20843927169238397
# mean_squared_error_test: 1.4420406870440754
# mean_absolute_error_test: 0.9131811843485359
# root_mean_squared_error_test: 1.200849985237155
# std_test: 0.6029111422350639
# Running time in minutes  :  0.0031086206436157227
#
#  #########################  Experiment Number  19 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 3072
# Number of remaining missing values: 0
# Percentage of values handled: 0.49%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.35672765 -1.37266655 -1.34233879]
# mean_cross_val_score: -1.357244327838858
# std_cross_val_score: 0.012386643336028144
# mean_cross_val_rmse: 1.1649961690199742
# r2_score: 0.2866563258391295
# mean_squared_error_test: 1.3112438168061353
# mean_absolute_error_test: 0.861033971882208
# root_mean_squared_error_test: 1.1450955492037052
# std_test: 0.7262249345845694
# Running time in minutes  :  0.001305230458577474
#
#  #########################  Experiment Number  20 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1078
# Number of rows in the cleaned dataset: 43603
#
# missing values method: mean
# Number of missing values handled: 5376
# Number of remaining missing values: 0
# Percentage of values handled: 0.54%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.33770068 -1.41113667 -1.32022577]
# mean_cross_val_score: -1.3563543767158615
# std_cross_val_score: 0.03938839270705699
# mean_cross_val_rmse: 1.1645045429416558
# r2_score: 0.268095879401553
# mean_squared_error_test: 1.3655913581403656
# mean_absolute_error_test: 0.8789976119159976
# root_mean_squared_error_test: 1.1685851950715298
# std_test: 0.7027448032223028
# Running time in minutes  :  0.0019244313240051269
#
#  #########################  Experiment Number  21 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 1130
# Number of remaining missing values: 0
# Percentage of values handled: 0.36%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.36389046 -1.38776426 -1.34982109]
# mean_cross_val_score: -1.3671586020714874
# std_cross_val_score: 0.015661666048426885
# mean_cross_val_rmse: 1.1692364278450456
# r2_score: 0.2785315787883432
# mean_squared_error_test: 1.3261784475028882
# mean_absolute_error_test: 0.8672810192240215
# root_mean_squared_error_test: 1.1515982144406478
# std_test: 0.7114294805903275
# Running time in minutes  :  0.0008049408594767252
#
#  #########################  Experiment Number  22 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 554
# Number of rows in the cleaned dataset: 44127
#
# missing values method: mean
# Number of missing values handled: 1306
# Number of remaining missing values: 0
# Percentage of values handled: 0.33%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.42090963 -1.36105919 -1.3836726 ]
# mean_cross_val_score: -1.3885471410476022
# std_cross_val_score: 0.02467575985489255
# mean_cross_val_rmse: 1.1783198973359987
# r2_score: 0.23876124853059844
# mean_squared_error_test: 1.4013125677947238
# mean_absolute_error_test: 0.8832445488589298
# root_mean_squared_error_test: 1.183770487803579
# std_test: 0.6800533860457134
# Running time in minutes  :  0.0008758902549743652
#
#  #########################  Experiment Number  23 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1078
# Number of rows in the cleaned dataset: 43603
#
# missing values method: mean
# Number of missing values handled: 6400
# Number of remaining missing values: 0
# Percentage of values handled: 0.54%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.29152771 -1.36234173 -1.27841459]
# mean_cross_val_score: -1.3107613469332617
# std_cross_val_score: 0.03686362866884283
# mean_cross_val_rmse: 1.1447726470891
# r2_score: 0.29685276552624806
# mean_squared_error_test: 1.3119365773108755
# mean_absolute_error_test: 0.862552718743232
# root_mean_squared_error_test: 1.145397999522819
# std_test: 0.7383489884449145
# Running time in minutes  :  0.002029422918955485
#
#  #########################  Experiment Number  24 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1
# Number of rows in the cleaned dataset: 44680
#
# missing values method: mean
# Number of missing values handled: 2154
# Number of remaining missing values: 0
# Percentage of values handled: 0.44%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.35735694 -1.36133126 -1.33140146]
# mean_cross_val_score: -1.350029886664079
# std_cross_val_score: 0.013271841300256446
# mean_cross_val_rmse: 1.1618937823463578
# r2_score: 0.2872338568337365
# mean_squared_error_test: 1.3101822191875918
# mean_absolute_error_test: 0.8619700391610571
# root_mean_squared_error_test: 1.144631914279692
# std_test: 0.7328345812132523
# Running time in minutes  :  0.0010088483492533367
#
#  #########################  Experiment Number  25 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 554
# Number of rows in the cleaned dataset: 44127
#
# missing values method: mean
# Number of missing values handled: 2290
# Number of remaining missing values: 0
# Percentage of values handled: 0.40%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.39547649 -1.33019699 -1.36377556]
# mean_cross_val_score: -1.3631496787475246
# std_cross_val_score: 0.026653922246968467
# mean_cross_val_rmse: 1.1674841846243529
# r2_score: 0.2503029748688814
# mean_squared_error_test: 1.380066189913062
# mean_absolute_error_test: 0.8777823662361064
# root_mean_squared_error_test: 1.1747621844071514
# std_test: 0.6922737624668791
# Running time in minutes  :  0.001105348269144694
#
#  #########################  Experiment Number  26 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# AST_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1078
# Number of rows in the cleaned dataset: 43603
#
# missing values method: mean
# Number of missing values handled: 4457
# Number of remaining missing values: 0
# Percentage of values handled: 0.51%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-1.36367308 -1.43722635 -1.36212735]
# mean_cross_val_score: -1.3876755938389298
# std_cross_val_score: 0.03504335768830496
# mean_cross_val_rmse: 1.1779033365364715
# r2_score: 0.2592456611669357
# mean_squared_error_test: 1.3821041515496546
# mean_absolute_error_test: 0.8888066097481885
# root_mean_squared_error_test: 1.1756292576954925
# std_test: 0.6784961255570401
# Running time in minutes  :  0.001555188496907552
#
# ...
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-0.43361616 -0.45124824 -0.44754389]
# mean_cross_val_score: -0.4441360960050041
# std_cross_val_score: 0.007590890171327802
# mean_cross_val_rmse: 0.6664109061812621
# r2_score: 0.4859848669332104
# mean_squared_error_test: 0.4400235035832135
# mean_absolute_error_test: 0.49966511727227964
# root_mean_squared_error_test: 0.6633426743269375
# std_test: 0.6546594391927084
# Running time in minutes  :  0.0053498148918151855
#
#  #########################  Experiment Number  251 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# COPD:
# COPD002(percent), COPD003(percent), COPD004(percent), COPD005(percent), COPD007(percent)
# Description: Chronic Obstructive Pulmonary Disease (COPD) related data
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# COPD_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 2530
# Number of rows in the cleaned dataset: 42142
#
# missing values method: mean
# Number of missing values handled: 5875
# Number of remaining missing values: 0
# Percentage of values handled: 0.19%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-0.34985516 -0.36406889 -0.36253915]
# mean_cross_val_score: -0.35882106698579525
# std_cross_val_score: 0.00637053624583412
# mean_cross_val_rmse: 0.5989930030680503
# r2_score: 0.5837470823032882
# mean_squared_error_test: 0.35633399765652957
# mean_absolute_error_test: 0.4463612418384622
# root_mean_squared_error_test: 0.5969371806618595
# std_test: 0.7055230481022674
# Running time in minutes  :  0.005711901187896729
#
#  #########################  Experiment Number  252 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# COPD:
# COPD002(percent), COPD003(percent), COPD004(percent), COPD005(percent), COPD007(percent)
# Description: Chronic Obstructive Pulmonary Disease (COPD) related data
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# COPD_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 2206
# Number of rows in the cleaned dataset: 42466
#
# missing values method: mean
# Number of missing values handled: 6556
# Number of remaining missing values: 0
# Percentage of values handled: 0.39%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-0.36481703 -0.3873404  -0.39818393]
# mean_cross_val_score: -0.38344712025497524
# std_cross_val_score: 0.013897379577265823
# mean_cross_val_rmse: 0.6191285984848349
# r2_score: 0.5682926497448195
# mean_squared_error_test: 0.37008060477080884
# mean_absolute_error_test: 0.45428908449787453
# root_mean_squared_error_test: 0.6083425061351614
# std_test: 0.6982700300648982
# Running time in minutes  :  0.0038478970527648926
#
#  #########################  Experiment Number  253 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# COPD_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 1975
# Number of rows in the cleaned dataset: 42697
#
# missing values method: mean
# Number of missing values handled: 11089
# Number of remaining missing values: 0
# Percentage of values handled: 0.35%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-3.70659495e-01 -3.62374104e-01 -1.58963725e+05]
# mean_cross_val_score: -52988.15265457525
# std_cross_val_score: 74936.0457961674
# mean_cross_val_rmse: 133.30444841025692
# r2_score: 0.5760293539512309
# mean_squared_error_test: 0.3800233511918726
# mean_absolute_error_test: 0.4498409258503406
# root_mean_squared_error_test: 0.6164603403235869
# std_test: 0.7199379155959703
# Running time in minutes  :  0.005913432439168294
#
#  #########################  Experiment Number  254 #########################
# Years selected for filtering: ['2014', '2015', '2016', '2017', '2018', '2019']
# Selected Categories :
#
# COPD:
# COPD002(percent), COPD003(percent), COPD004(percent), COPD005(percent), COPD007(percent)
# Description: Chronic Obstructive Pulmonary Disease (COPD) related data
#
# Gender:
# Total_All, MALE_All, FEMALE_All, Male_0_4, Male_5_9, Male_10_14, Male_15_19, Male_20_24, Male_25_29, Male_30_34, Male_35_39, Male_40_44, Male_45_49, Male_50_54, Male_55_59, Male_60_64, Male_65_69, Male_70_74, Male_75_79, Male_80_84, Male_85+, Female_0_4, Female_5_9, Female_10_14, Female_15_19, Female_20_24, Female_25_29, Female_30_34, Female_35_39, Female_40_44, Female_45_49, Female_50_54, Female_55_59, Female_60_64, Female_65_69, Female_70_74, Female_75_79, Female_80_84, Female_85+
# Description: Demographic data based on gender
#
# Income:
# Weighted_Total_annual_income_(£), Weighted_Net_annual_income_(£), Weighted_Net_annual_income_before_housing_costs_(£), Weighted_Net_annual_income_after_housing_costs_(£)
# Description: Economic data related to income
#
# Deprivation:
# Weighted_Index_of_Multiple_Deprivation_(IMD), Weighted_Income, Weighted_Employment, Weighted_Education,_Skills_and_Training, Weighted_Health_Deprivation_and_Disability, Weighted_Crime, Weighted_Barriers_to_Housing_and_Services, Weighted_Living_Environment
# Description: Data related to deprivation index
#
# Parks_and_Housing:
# Weighted_ParksOnly_Average_distance_to_nearest_Park_or_Public_Garden_(m), Weighted_ParksOnly_Average_size_of_nearest_Park_or_Public_Garden_(m2), Weighted_ParksOnly_Average_number_of_Parks_or_Public_Gardens_within_1,000_m_radius, Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_300m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksOnly_Number_of_built_up_area_postcodes__within_900m_of_a_Park_or_Public_Garden_(percentage), Weighted_ParksAndPlayingFields_Average_distance_to_nearest_Park_Public_Garden_or_Playing_Field_(m), Weighted_ParksAndPlayingFields_Average_size_of_nearest_Park_Public_Garden_or_Playing_Field_(m2), Weighted_ParksAndPlayingFields_Average_number_of__Parks_Public_Gardens_or_Playing_Fields_within_1,000_m_radius, Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_300m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_ParksAndPlayingFields_Number_of_built_up_area_postcodes__within_900m_of_a_Park_Public_Garden_or_Playing_Field_(percentage), Weighted_Houses_Percentage_of_adresses_with_private_outdoor_space, Weighted_Houses_Average_size_of_private_outdoor_space_(m2), Weighted_Houses_Median_size_of_private_outdoor_space_(m2), Weighted_Flats_Percentage_of_adresses_with_private_outdoor_space, Weighted_Flats_Average_size_of_private_outdoor_space_(m2), Weighted_Flats_Average_number_of_flats_sharing_a_garden, Weighted_Total_Percentage_of_adresses_with_private_outdoor_space
# Description: Data related to parks and housing
#
# Obesity:
# Obesity_Prevalence(per_cent)
# Description: Obesity-related data
#
# Smoking:
# SMOK002(percent), SMOK004(percent), SMOK005(percent)
# Description: Smoking-related data
#
# COPD_Prevalence
# Clean outliers method: IQR
# Threshold: 10
# Action: remove outliers
# Number of outliers removed: 2530
# Number of rows in the cleaned dataset: 42142
#
# missing values method: mean
# Number of missing values handled: 6763
# Number of remaining missing values: 0
# Percentage of values handled: 0.20%
#
# Normalization method: Min-Max
#
# The param grid for linear_regression model is:
#
# {}
# model_name: linear_regression
# cv: 3
# best_model: LinearRegression()
# best_params: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# cross_val_scores: [-0.34122717 -0.35470121 -0.36241096]
# mean_cross_val_score: -0.3527797814464962
# std_cross_val_score: 0.00875432073959358
# mean_cross_val_rmse: 0.5939067627321831
# r2_score: 0.5952196461886491
# mean_squared_error_test: 0.34651289039496036
# mean_absolute_error_test: 0.4403270032515035
# root_mean_squared_error_test: 0.5886534552646068
# std_test: 0.7168923462831693
# Running time in minutes  :  0.006471709410349528
